# %%
import time
from numpy import cos, pi, exp, e, sqrt
import numpy
from numba import njit
import matplotlib.pyplot as plt

# %% [markdown]
# #Реализация алгоритма ETFSS на Python с использованием Numba

# %%
n_args_count_ = 1  # количество x-ов, подаваемых в тестовую функцию
iter_max_ = 500  # больше 500 не нужно
number_of_agents_ = 50  # количество агентов популяции (20-40-50 должно быть)
max_weight_ = 100  # максимальный вес рыбы

# %% [markdown]
# ##Реализация алгоритма

# %%
@njit
def main_function(n_args_count, iter_max, number_of_agents, max_weight):
    y = 5

    step_ind = numpy.zeros(iter_max)
    step_vol = numpy.zeros(iter_max)
    p_qbest_list = numpy.zeros((iter_max, n_args_count))  # массив p_qbest в разные моменты поколений
    w = numpy.zeros((iter_max, number_of_agents))
    P = numpy.zeros((iter_max, number_of_agents, n_args_count))  # Начальная популяция
    F = numpy.zeros((iter_max, number_of_agents))  # значение функции для каждого агента

    t = 0  # текущий номер поколения
    step_ind[t] = 0.05
    step_vol[t] = 0.05
    w[t] += max_weight / 2
    P[t] = generate_agents(number_of_agents, n_args_count)  # Случано сгенерированное текущее поколение

    p_qbest = P[t][0]
    for i in P[t]:
        if f(p_qbest) > f(i):
            p_qbest = i
    p_qbest_list[t] = p_qbest

    f_t = numpy.zeros(number_of_agents)
    for i in range(number_of_agents):
        f_I = f(P[t][i])
        f_t[i] = f_I
        # f_t.append(f_I)

    # значение функции для каждого агента
    F[t] = f_t

    # макс кол-во иттераций
    # критерий останова может быть и другим
    # t не только как поколение, но и кол-во иттераций
    while t < iter_max - 1:
        t += 1
        step_ind[t] = step_ind[0] * exp(-y * t / iter_max)
        step_vol[t] = step_vol[0] * exp(-y * t / iter_max)

        P[t] = numpy.copy(P[t - 1])
        w[t] = numpy.copy(w[t - 1])
        # для каждого агента выполнить
        for i in range(number_of_agents):
            r1 = numpy.random.uniform(0, 1, n_args_count)

            P[t][i] += (r1 * step_ind[t])

            F[t][i] = f(P[t][i])  # значение f для P_it
            if F[t][i] >= F[t - 1][i]:
                P[t][i] = P[t - 1][i]
                F[t][i] = f(P[t][i])

        for i in range(number_of_agents):
            if max(F[t] - F[t - 1]) != 0:
                # кормление
                w[t][i] += (F[t][i] - F[t - 1][i]) / (max(F[t] - F[t - 1]))

        # вычисляем вектор коллективно-инстинктивного перемещения
        I_t = numpy.zeros(n_args_count)

        P_mul_F = numpy.zeros(
            (number_of_agents, n_args_count))

        delta_F = F[t] - F[t - 1]
        for i in range(number_of_agents):
            P_mul_F[i] = (P[t][i] - P[t - 1][i]) * delta_F[i]

        for j in range(n_args_count):
            s = numpy.sum(P_mul_F[:][j])
            I_t[j] = s
        I_t /= numpy.sum(delta_F)
        # Применяем оператор коллективно-инстинктивного перемещения к каждому агенту
        P[t] += I_t

        # Вычисляем Бариоцентр
        B_t = numpy.zeros(n_args_count)
        for j in range(n_args_count):
            sm = 0
            for i in range(number_of_agents):
                sm += P[t][i][j] * w[t][i]
            B_t[j] = sm
        sm2 = numpy.sum(w[t])
        B_t /= sm2

        # для каждого агента выполнять
        for i in range(number_of_agents):
            r2 = numpy.random.uniform(0, 1, n_args_count)
            if numpy.sum(w[t]) > numpy.sum(w[t - 1]):
                for j in range(len(P[t][0])):
                    P[t][i][j] -= step_vol[t] * r2[j] * (P[t][i][j] - B_t[j]) / abs((P[t][i][j] - B_t[j]))
            else:
                for j in range(len(P[t][0])):
                    P[t][i][j] += step_vol[t] * r2[j] * (P[t][i][j] - B_t[j]) / abs((P[t][i][j] - B_t[j]))

        p_qbest_t = P[t][0]
        for i in P[t]:
            if f(p_qbest_t) > f(i):
                p_qbest_t = i
        if f(p_qbest_t) < f(p_qbest):
            p_qbest = p_qbest_t
        p_qbest_list[t] = p_qbest

    return p_qbest_list

# %%
def draw_graphic(f_val, functon_name, iter_max):
    plt.grid(color="black", linestyle="--", linewidth=0.5)
    plt.plot(numpy.arange(iter_max), f_val, color='fuchsia')
    plt.xlabel("Номер поколения")
    plt.ylabel("f(p_qbest)")
    plt.title(f'Тестовая функция {functon_name}')
    plt.show()

# %%
def draw_distribution_graphic(best_values, function_name):
    plt.title("Распределение для функции " + function_name)
    plt.xlabel("Номер теста")
    plt.ylabel("Лучшее найденное значение")
    plt.scatter(numpy.arange(10), best_values, c="black")
    plt.plot(numpy.arange(10), numpy.zeros(10), c="fuchsia")
    plt.fill_between(numpy.arange(10),
                     numpy.zeros(10) - 0.001,
                     numpy.zeros(10) + 0.001,
                     color="fuchsia",
                     alpha=0.2)
    plt.show()

# %%
def start_test(function_name, n_args_count, iter_max, number_of_agents, max_weight):
    best_qbest_tests = list()  # лучшие значения алгоритма в результате 10 запусков
    for i in range(10):
        start = time.time()
        best_lst = main_function(n_args_count, iter_max, number_of_agents, max_weight)
        best = best_lst[-1]
        end = time.time() - start
        best_qbest_tests.append(f(best))
        print(f'------------------------TEST NUMBER: {i + 1}------------------------')
        print(f'Coordinates of p_qbest:\t\t\t{best}')
        print(f'The function value of pqbest:\t\t{f(best)}')
        print(f'Algorithm running time:\t\t\t{end} s')
        f_val = [f(i) for i in best_lst]
        draw_graphic(f_val, function_name, iter_max)
    draw_distribution_graphic(best_qbest_tests, function_name)

# %% [markdown]
# ##Тестовая функция Растригина
# ![picture_of_Rastrigen](src/растригина.png)

# %%
@njit
def f(x):  # Тестовая функция Растригина
    A = 10
    result = 0
    for i in x:
        result += i * i - A * cos(2 * pi * i)
    result += A * len(x)

    return result

# %% [markdown]
# ##Генерация начальных агентов

# %%
@njit
def generate_agents(number_of_agents, n_args_count):
    return numpy.random.uniform(-5.12, 5.12, size=(number_of_agents, n_args_count))

# %%
start_test("Растригина", n_args_count_, iter_max_, number_of_agents_, max_weight_)
# Out:
# ------------------------TEST NUMBER: 1------------------------
# Coordinates of p_qbest:			[-0.00011411]
# The function value of pqbest:		2.5831190129110837e-06
# Algorithm running time:			6.57544207572937 s
# ------------------------TEST NUMBER: 2------------------------
# Coordinates of p_qbest:			[0.00256171]
# The function value of pqbest:		0.0013018920693816938
# Algorithm running time:			0.029918432235717773 s
# ------------------------TEST NUMBER: 3------------------------
# Coordinates of p_qbest:			[-0.00044326]
# The function value of pqbest:		3.898013621927987e-05
# Algorithm running time:			0.030511856079101562 s
# ------------------------TEST NUMBER: 4------------------------
# Coordinates of p_qbest:			[-9.32232468e-05]
# The function value of pqbest:		1.7241410219526188e-06
# Algorithm running time:			0.024967193603515625 s
# ------------------------TEST NUMBER: 5------------------------
# Coordinates of p_qbest:			[-1.14342982e-05]
# The function value of pqbest:		2.593841230691396e-08
# Algorithm running time:			0.020624399185180664 s
# ------------------------TEST NUMBER: 6------------------------
# Coordinates of p_qbest:			[0.00011529]
# The function value of pqbest:		2.6370146635201763e-06
# Algorithm running time:			0.020334243774414062 s
# ------------------------TEST NUMBER: 7------------------------
# Coordinates of p_qbest:			[-0.00015964]
# The function value of pqbest:		5.0561469659982095e-06
# Algorithm running time:			0.020063161849975586 s
# ------------------------TEST NUMBER: 8------------------------
# Coordinates of p_qbest:			[9.29287462e-06]
# The function value of pqbest:		1.713264907721168e-08
# Algorithm running time:			0.020505189895629883 s
# ------------------------TEST NUMBER: 9------------------------
# Coordinates of p_qbest:			[-0.00026313]
# The function value of pqbest:		1.373622684575082e-05
# Algorithm running time:			0.01961231231689453 s
# ------------------------TEST NUMBER: 10------------------------
# Coordinates of p_qbest:			[5.89464936e-06]
# The function value of pqbest:		6.893507986660552e-09
# Algorithm running time:			0.0160067081451416 s

# %% [markdown]
# ##Тестовая функция Экли
# ![picture_of_Ekli](src/Экли.png)

# %%
@njit
def f(x):  # Тестовая функция Экли
    result = -20 * exp(-0.2 * sqrt(0.5 * (x[0] * x[0] + x[1] * x[1]))) \
             - exp(0.5 * (cos(2 * pi * x[0]) + cos(2 * pi * x[1]))) + e + 20
    return result

# %% [markdown]
# ##Генерация начальных агентов

# %%
@njit
def generate_agents(number_of_agents, n_args_count):
    return numpy.random.uniform(-5, 5, size=(number_of_agents, n_args_count))

# %%
start_test("Экли", n_args_count_, iter_max_, number_of_agents_, max_weight_)
# Out:
# ------------------------TEST NUMBER: 1------------------------
# Coordinates of p_qbest:			[-6.30484047e-05]
# The function value of pqbest:		0.0001784336683776644
# Algorithm running time:			0.0194242000579834 s
# ------------------------TEST NUMBER: 2------------------------
# Coordinates of p_qbest:			[-3.33711697e-05]
# The function value of pqbest:		9.441757581285515e-05
# Algorithm running time:			0.023547649383544922 s
# ------------------------TEST NUMBER: 3------------------------
# Coordinates of p_qbest:			[-0.00016557]
# The function value of pqbest:		0.0004690219290743869
# Algorithm running time:			0.02399158477783203 s
# ------------------------TEST NUMBER: 4------------------------
# Coordinates of p_qbest:			[-0.00037083]
# The function value of pqbest:		0.0010525244855656979
# Algorithm running time:			0.02400970458984375 s
# ------------------------TEST NUMBER: 5------------------------
# Coordinates of p_qbest:			[6.3974756e-06]
# The function value of pqbest:		1.8095883344670938e-05
# Algorithm running time:			0.020328760147094727 s
# ------------------------TEST NUMBER: 6------------------------
# Coordinates of p_qbest:			[-0.00038863]
# The function value of pqbest:		0.0011032303339355565
# Algorithm running time:			0.015438079833984375 s
# ------------------------TEST NUMBER: 7------------------------
# Coordinates of p_qbest:			[-0.00016391]
# The function value of pqbest:		0.00046430991203649796
# Algorithm running time:			0.02018117904663086 s
# ------------------------TEST NUMBER: 8------------------------
# Coordinates of p_qbest:			[-0.00083692]
# The function value of pqbest:		0.002385813295113337
# Algorithm running time:			0.028536081314086914 s
# ------------------------TEST NUMBER: 9------------------------
# Coordinates of p_qbest:			[6.08006145e-05]
# The function value of pqbest:		0.00017206854463580612
# Algorithm running time:			0.025035858154296875 s
# ------------------------TEST NUMBER: 10------------------------
# Coordinates of p_qbest:			[-0.00043945]
# The function value of pqbest:		0.0012481052427766315
# Algorithm running time:			0.015229225158691406 s

# %% [markdown]
# ##Тестовая функция Сферы
# ![picture_of_Sphere](src/сфера.png)

# %%
@njit
def f(x):  # Тестовая функция Сферы
    result = 0
    for i in x:
        result += i * i
    return result

# %% [markdown]
# ##Генерация начальных агентов

# %%
@njit
def generate_agents(number_of_agents, n_args_count):
    return numpy.random.uniform(-10, 10, size=(number_of_agents, n_args_count))

# %%
start_test("Сферы", n_args_count_, iter_max_, number_of_agents_, max_weight_)
# Out:
# ------------------------TEST NUMBER: 1------------------------
# Coordinates of p_qbest:			[-4.24469439e-05]
# The function value of pqbest:		1.8017430494064176e-09
# Algorithm running time:			0.020985126495361328 s
# ------------------------TEST NUMBER: 2------------------------
# Coordinates of p_qbest:			[0.00099085]
# The function value of pqbest:		9.817916763676512e-07
# Algorithm running time:			0.01987290382385254 s
# ------------------------TEST NUMBER: 3------------------------
# Coordinates of p_qbest:			[-0.00049739]
# The function value of pqbest:		2.4739782657933544e-07
# Algorithm running time:			0.019778013229370117 s
# ------------------------TEST NUMBER: 4------------------------
# Coordinates of p_qbest:			[-0.00032199]
# The function value of pqbest:		1.036798256209266e-07
# Algorithm running time:			0.023954153060913086 s
# ------------------------TEST NUMBER: 5------------------------
# Coordinates of p_qbest:			[-0.00133966]
# The function value of pqbest:		1.7946998622774673e-06
# Algorithm running time:			0.02079010009765625 s
# ------------------------TEST NUMBER: 6------------------------
# Coordinates of p_qbest:			[0.00013756]
# The function value of pqbest:		1.8923731826593938e-08
# Algorithm running time:			0.012516260147094727 s
# ------------------------TEST NUMBER: 7------------------------
# Coordinates of p_qbest:			[0.00312407]
# The function value of pqbest:		9.759841329519958e-06
# Algorithm running time:			0.019629478454589844 s
# ------------------------TEST NUMBER: 8------------------------
# Coordinates of p_qbest:			[-0.0003524]
# The function value of pqbest:		1.2418374651002136e-07
# Algorithm running time:			0.01957535743713379 s
# ------------------------TEST NUMBER: 9------------------------
# Coordinates of p_qbest:			[-5.82508088e-05]
# The function value of pqbest:		3.3931567258236648e-09
# Algorithm running time:			0.020644664764404297 s
# ------------------------TEST NUMBER: 10------------------------
# Coordinates of p_qbest:			[1.4540177e-05]
# The function value of pqbest:		2.1141674733858523e-10
# Algorithm running time:			0.013802528381347656 s
